# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Side by Side bars

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
# one way from codeacademy
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
middle_school_a = [80, 85, 84, 83, 86]
middle_school_b = [73, 78, 77, 82, 86]

def create_x(t, w, n, d):
    return [t*x + w*n for x in range(d)]

#t = 2 # There are two sets of data: A and B
#w = 0.8 # We generally want bars to be 0.8
#n = 1 # A is first set of data
#d = 5 # There are 5 topics we're plotting

# Make your chart here
school_a_x = create_x(2, 0.8, 1, 5)
school_b_x = create_x(2, 0.8, 2, 5)

middle_x = [ (a + b) / 2.0 for a, b in zip(school_a_x, school_b_x)]

plt.figure(figsize=(10,8))

ax = plt.subplot()
ax.bar(school_a_x, middle_school_a, label='Middle School A')
ax.bar(school_b_x, middle_school_b, label='Middle School B')
ax.set_xticks(middle_x)
ax.set_xticklabels(unit_topics)
ax.legend()
ax.set_title('Test Averages on Different Units')
ax.set_xlabel('Unit')
ax.set_ylabel('Test Average')

#plt.savefig('my_side_by_side.png')
plt.show()

# %%
# not quite sure how to make it good
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
middle_school_a = [80, 85, 84, 83, 86]
middle_school_b = [73, 78, 77, 82, 86]

x = np.arange(len(unit_topics)) # location labels
width = 0.8


fig, ax = plt.subplots()
plt.figure(figsize=(10, 8))

bar1 = ax.bar(x - width/2, middle_school_a, width, label='Middle School A')
bar2 = ax.bar(x + width/2, middle_school_b, width, label='Middle School B')

ax.set_xticks(x)
ax.set_xticklabels(unit_topics)
ax.set_xlabel('Unit')
ax.set_ylabel('Test Average')
ax.set_title('Test Averages on Different Units')
ax.legend()




plt.tight_layout()
plt.show()

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27]
sales2 = [65, 82, 36, 68, 38, 40]


ax = plt.subplot()

n = 1  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar
store1_x = [t*element + w*n for element
             in range(d)]

plt.bar(store1_x, sales1)

n = 2  # This is our second dataset (out of 2)
t = 2 # Number of datasets
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar
store2_x = [t*element + w*n for element
             in range(d)]

plt.bar(store2_x, sales2)

ax.set_xlabel('Drinks')
ax.set_ylabel('Sales')



plt.show()

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27]
sales2 = [65, 82, 36, 68, 38, 40]


x = np.arange(len(drinks))  # labels location
widht = 0.8

fig, ax = plt.subplots()
bar1 = ax.bar(x - width/2, sales1, width, label='Store 1')
bar2 = ax.bar(x + width/2, sales2, width, label='Store 2')

ax.set_ylabel('SALES')
ax.set_title('Sales on different store')
ax.set_xticks(x)
ax.set_xticklabels(drinks)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Stacked Bars

# %%
video_game_hours = [1, 2, 2, 1, 2]
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
book_hours = [2, 3, 4, 2, 1]

l = np.arange(len(days))  #labels location

fig, ax1 = plt.subplots()

b1 = ax1.bar(range(len(video_game_hours)), video_game_hours, label='Books') 
b2 = ax1.bar(range(len(book_hours)), book_hours, bottom=video_game_hours, label='Videogames')

ax1.set_ylabel('Hours')
ax1.set_title('Breakdown of entertainment hours')
ax1.set_xticks(l)
ax1.set_xticklabels(days)
ax1.legend()

plt.tight_layout()
plt.show()

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
As = [6, 3, 4, 3, 5]
Bs = [8, 12, 8, 9, 10]
Cs = [13, 12, 15, 13, 14]
Ds = [2, 3, 3, 2, 1]
Fs = [1, 0, 0, 3, 0]

x = np.arange(len(unit_topics)) # x labels location

# bottoms 
c_bottom = np.add(As, Bs)
d_bottom = np.add(c_bottom, Cs)
f_bottom = np.add(d_bottom, Ds)

fig = plt.figure(figsize=(10,8))
fig, ax = plt.subplots()

a = ax.bar(np.arange(len(As)), As, label='A')
b = ax.bar(np.arange(len(Bs)), Bs, bottom=As, label='B')
c = ax.bar(np.arange(len(Cs)), Cs, bottom=c_bottom, label='C')
d = ax.bar(np.arange(len(Ds)), Ds, bottom=d_bottom, label='D')
f = ax.bar(np.arange(len(Fs)), Fs, bottom=f_bottom, label='F')

ax.set_xticks(x)
ax.set_xticklabels(unit_topics)
ax.set_title('Grade distribution')
ax.set_xlabel('Unit')
ax.set_ylabel('Number of Students')
ax.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# ## ERROR BARS
#
# https://problemsolvingwithpython.com/06-Plotting-with-Matplotlib/06.07-Error-Bars/

# %%
# Data
aluminum = np.array([6.4e-5 , 3.01e-5 , 2.36e-5, 3.0e-5, 7.0e-5, 4.5e-5, 3.8e-5,
                     4.2e-5, 2.62e-5, 3.6e-5])
copper = np.array([4.5e-5 , 1.97e-5 , 1.6e-5, 1.97e-5, 4.0e-5, 2.4e-5, 1.9e-5, 
                   2.41e-5 , 1.85e-5, 3.3e-5 ])
steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
                  1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
aluminum_mean = np.mean(aluminum)
copper_mean = np.mean(copper)
steel_mean = np.mean(steel)


# Calculate the standard deviation
aluminum_std = np.std(aluminum)
copper_std = np.std(copper)
steel_std = np.std(steel)


# Define labels, positions, bar heights and error bar heights
labels = ['Aluminum', 'Copper', 'Steel']
x_pos = np.arange(len(labels))
CTEs = [aluminum_mean, copper_mean, steel_mean]
error = [aluminum_std, copper_std, steel_std]

fig, ax = plt.subplots()

ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)

ax.set_ylabel('Coefficient of Thermal Expansion(\degreeC−1)')
ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
#plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
ounces_of_milk = [6, 9, 4, 0, 9, 0]
error = [0.6, 0.9, 0.4, 0, 0.9, 0]

x = np.arange(len(drinks))  # position of labels

fig, ax = plt.subplots()

ax.bar(np.arange(len(ounces_of_milk)), ounces_of_milk, yerr=error, capsize=5, label='Milk')  # bar plot with error
ax.set_xticks(x)
ax.set_xticklabels(drinks)
ax.set_title('Amount of milk in each 12oz drink')
ax.set_ylabel('Milk')

ax.legend()

plt.show()

# %%
past_years_averages = [82, 84, 83, 86, 74, 84, 90]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006]
error = [1.5, 2.1, 1.2, 3.2, 2.3, 1.7, 2.4]

x = np.arange(len(years))

fig, ax = plt.subplots()

ax.bar(np.arange(len(past_years_averages)), past_years_averages, yerr=error, capsize=5)

ax.set_xticks(x)
ax.set_xticklabels(years)
ax.set_xlabel('Year')
ax.set_ylabel('Test average')
ax.set_title('Final Exam Averages')

plt.axis([-0.5, 6.5, 70, 95])
plt.figure(figsize=(10, 8)) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## FILL BETWEEN
# This data is a projection of future revenue. We don’t know that this will be the revenue, but it’s an estimate based on the patterns of past years. We can say that the real revenue will probably be plus or minus 10% of each value

# %%
months = range(12)
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
revenue = [16000, 14000, 17500, 19500, 21500, 21500, 22000, 23000, 20000, 19500, 18000, 16500]

# create the lower and upper bound to fill
y_lower = [i - (0.1 * i) for i in revenue]
y_upper = [i + (0.1 * i) for i in revenue]

# fig so i can plot
fig, ax = plt.subplots()
ax.plot(months, revenue)
ax.set_xticks(months)
ax.set_xticklabels(month_names)
ax.fill_between(months, y_lower, y_upper,color='C0', alpha=0.2)

plt.show()

# %%
hours_reported =[3, 2.5, 2.75, 2.5, 2.75, 3.0, 3.5, 3.25, 3.25,  3.5, 3.5, 3.75, 3.75,4, 4.0, 3.75,  
                 4.0, 4.25, 4.25, 4.5, 4.5, 5.0, 5.25, 5, 5.25, 5.5, 5.5, 5.75, 5.25, 4.75]

exam_scores = [52.53, 59.05, 61.15, 61.72, 62.58, 62.98, 64.99, 67.63, 68.52, 70.29, 71.33, 72.15, 72.67, 
               73.85, 74.44, 75.62, 76.81, 77.82, 78.16, 78.94, 79.08, 80.31, 80.77, 81.37, 85.13, 85.38, 
               89.34, 90.75, 97.24, 98.31]

lower = [i - (0.2 * i) for i in hours_reported]
upper = [i + (0.2 * i) for i in hours_reported]

fig = plt.figure(figsize=(10,8))
fig, ax = plt.subplots()

ax.plot(exam_scores, hours_reported)
ax.fill_between(exam_scores, lower, upper, color='C0', alpha=0.2)


plt.show()

# %% [markdown]
# ## PIE CHARTS

# %%
from matplotlib import pyplot as plt
import numpy as np

payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

#make your pie chart here
fig, ax = plt.subplots()
ax.pie(payment_method_freqs, labels=payment_method_names, )
ax.axis('equal')
plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
num_hardest_reported = [1, 3, 10, 15, 1]

fig = plt.figure(figsize=(10,8))
fig, ax = plt.subplots()

ax.pie(num_hardest_reported, labels=unit_topics, autopct='%d%%')
ax.axis('equal')
ax.set_title('Hardest Topics')

plt.show()

# %% [markdown]
# ## HISTOGRAMS

# %%
age = [1,1,2,3,3,5,7,8,9,10,
10,11,11,13,13,15,16,17,18,18,
18,19,20,21,21,23,24,24,25,25,
25,25,26,26,26,27,27,27,27,27,
29,30,30,31,33,34,34,34,35,36,
36,37,37,38,38,39,40,41,41,42,
43,44,45,45,46,47,48,48,49,50,
51,52,53,54,55,55,56,57,58,60,
61,63,64,65,66,68,70,71,72,74,
75,77,81,83,84,87,89,90,90,91]

# basic histogram plot
#plt.style.use('ggplot') # add style to the histogram
plt.hist(age, bins=10)
  
plt.show()

# %%
# revert plt.style.use to the defualt version
# %matplotlib inline
plt.rcParams.update(plt.rcParamsDefault)

# %%
# temporary change of style to use only on 1 block

#with plt.style.context('dark_background'):
    #plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
#plt.show()

# %%
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
np.random.seed(19680801)

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data

n, bins, patches = ax.hist(x, num_bins, density=True)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# %%
exam_scores1 = [62.58, 67.63, 81.37, 52.53, 62.98, 72.15, 59.05, 
                73.85, 97.24, 76.81, 89.34, 74.44, 68.52, 85.13, 90.75, 70.29, 
                75.62, 85.38, 77.82, 98.31, 79.08, 61.72, 71.33, 80.77, 80.31, 78.16, 61.15, 64.99, 72.67, 78.94]

exam_scores2 = [72.38, 71.28, 79.24, 83.86, 84.42, 79.38, 75.51, 
                76.63, 81.48,78.81,79.23,74.38,79.27,81.07,75.42,90.35,82.93,86.74,81.33,95.1,
                86.57,83.66,85.58,81.87,92.14,72.15,91.64,74.21,89.04,76.54,81.9,96.5,80.05,74.77,
                72.26,73.23,92.6,66.22,70.09,77.2]

fig = plt.figure(figsize=(10, 8))
fig, ax = plt.subplots()

ax.hist(exam_scores1, bins=12, histtype='step', density=True, linewidth=2, label='1st Yr Teaching')
ax.hist(exam_scores2, bins=12, histtype='step', density=True, linewidth=2, label='2nd Yr Teaching')

ax.legend()
ax.set_ylabel('Frequency')
ax.set_xlabel('Percentage')
ax.set_title('Final Exam Score Distribution')
plt.show()
